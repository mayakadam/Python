# %%
import pandas as pd
import numpy as np
import collections
from collections import *
import math
import cmath
from math import *
import matplotlib.pyplot as plt
from matplotlib.pyplot import *

# %%
gdp = pd.read_csv('D:\\Python\\Python36\\Practice\\World_GDP.csv')

# %%
gdp.head()
# Out:
#   Country Name Country Code                       Series Name  \
# 0       Poland          POL      GDP per capita (current US$)
# 1       Poland          POL  GDP per capita growth (annual %)
# 2       Poland          POL             GDP growth (annual %)
# 3       Poland          POL                 GDP (current US$)
# 4      Germany          DEU      GDP per capita (current US$)
#
#          Series Code  1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  \
# 0     NY.GDP.PCAP.CD   1.698007e+03   2.192666e+03   2.411859e+03
# 1  NY.GDP.PCAP.KD.ZG   0.000000e+00  -7.344791e+00   2.201066e+00
# 2  NY.GDP.MKTP.KD.ZG   0.000000e+00  -7.015579e+00   2.514979e+00
# 3     NY.GDP.MKTP.CD   6.471237e+10   8.386113e+10   9.252777e+10
# 4     NY.GDP.PCAP.CD   2.221957e+04   2.326938e+04   2.633354e+04
#
#    1993 [YR1993]  1994 [YR1994]  1995 [YR1995]  ...  2006 [YR2006]  \
# 0   2.449302e+03   2.819689e+03   3.612160e+03  ...   8.999740e+03
# ...

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   42 non-null     object
#  1   Country Code   40 non-null     object
#  2   Series Name    40 non-null     object
#  3   Series Code    40 non-null     object
#  4   1990 [YR1990]  40 non-null     float64
#  5   1991 [YR1991]  40 non-null     float64
#  6   1992 [YR1992]  40 non-null     float64
#  7   1993 [YR1993]  40 non-null     float64
#  8   1994 [YR1994]  40 non-null     float64
#  9   1995 [YR1995]  40 non-null     float64
#  10  1996 [YR1996]  40 non-null     float64
#  11  1997 [YR1997]  40 non-null     float64
#  12  1998 [YR1998]  40 non-null     float64
#  13  1999 [YR1999]  40 non-null     float64
#  14  2000 [YR2000]  40 non-null     float64
#  15  2001 [YR2001]  40 non-null     float64
#  16  2002 [YR2002]  40 non-null     float64
# ...

# %%
gdp[(gdp['Country Code'] =='POL') & (gdp['Series Code'] =='NY.GDP.PCAP.CD')]
# Out:
#   Country Name Country Code                   Series Name     Series Code  \
# 0       Poland          POL  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#    1990 [YR1990]  1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  1994 [YR1994]  \
# 0    1698.006922     2192.66598    2411.859496    2449.301908    2819.689466
#
#    1995 [YR1995]  ...  2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  \
# 0    3612.159514  ...    8999.739627    11247.55148     13906.2182
#
#    2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# 0    11440.57813    12597.45879    13891.14169    13142.04599    13776.45476
#
#    2014 [YR2014]  2015 [YR2015]
# 0    14337.20637    12494.46619
#
# [1 rows x 30 columns]

# %%
print(gdp[gdp['Series Name'] =='GDP per capita (current US$)']['1990 [YR1990]'])
# Out:
# 0      1698.006922
# 4     22219.572530
# 8      1704.740304
# 12     3901.525437
# 16     2395.564582
# 20        0.000000
# 24        0.000000
# 28    21795.237830
# 32     1569.739433
# 36    19095.467000
# Name: 1990 [YR1990], dtype: float64

# %%
gdp_df = pd.DataFrame(gdp)

# %%
gdp_df_t = gdp_df.transpose()

# %%
gdp_df_t
# Out:
#                                          0                                 1   \
# Country Name                         Poland                            Poland
# Country Code                            POL                               POL
# Series Name    GDP per capita (current US$)  GDP per capita growth (annual %)
# Series Code                  NY.GDP.PCAP.CD                 NY.GDP.PCAP.KD.ZG
# 1990 [YR1990]                       1698.01                                 0
# 1991 [YR1991]                       2192.67                          -7.34479
# 1992 [YR1992]                       2411.86                           2.20107
# 1993 [YR1993]                        2449.3                           3.47468
# 1994 [YR1994]                       2819.69                           5.07086
# 1995 [YR1995]                       3612.16                            6.8068
# 1996 [YR1996]                       4066.84                           6.15813
# ...

# %%
gdp_df_t_pol = gdp_df_t[0]

# %%
gdp_df_t_pol.pop('Country Name')
gdp_df_t_pol.pop('Country Code')
gdp_df_t_pol.pop('Series Name')
gdp_df_t_pol.pop('Series Code')
# Out:
# 'NY.GDP.PCAP.CD'

# %%
gdp_df_t_pol
# Out:
# 1990 [YR1990]    1698.01
# 1991 [YR1991]    2192.67
# 1992 [YR1992]    2411.86
# 1993 [YR1993]     2449.3
# 1994 [YR1994]    2819.69
# 1995 [YR1995]    3612.16
# 1996 [YR1996]    4066.84
# 1997 [YR1997]    4076.35
# 1998 [YR1998]    4483.24
# 1999 [YR1999]    4351.37
# 2000 [YR2000]    4492.73
# 2001 [YR2001]     4981.2
# 2002 [YR2002]    5196.93
# 2003 [YR2003]    5693.38
# 2004 [YR2004]    6639.96
# 2005 [YR2005]    7976.07
# 2006 [YR2006]    8999.74
# 2007 [YR2007]    11247.6
# 2008 [YR2008]    13906.2
# 2009 [YR2009]    11440.6
# 2010 [YR2010]    12597.5
# 2011 [YR2011]    13891.1
# 2012 [YR2012]      13142
# 2013 [YR2013]    13776.5
# 2014 [YR2014]    14337.2
# 2015 [YR2015]    12494.5
# Name: 0, dtype: object

# %%
gdp_df_t_ger = gdp_df_t[4]

# %%
gdp_df_t_ger.pop('Country Name')
gdp_df_t_ger.pop('Country Code')
gdp_df_t_ger.pop('Series Name')
gdp_df_t_ger.pop('Series Code')
# Out:
# 'NY.GDP.PCAP.CD'

# %%
gdp_df_t_ger
# Out:
# 1990 [YR1990]    22219.6
# 1991 [YR1991]    23269.4
# 1992 [YR1992]    26333.5
# 1993 [YR1993]    25488.5
# 1994 [YR1994]    27087.6
# 1995 [YR1995]    31729.7
# 1996 [YR1996]    30564.2
# 1997 [YR1997]    27045.7
# 1998 [YR1998]    27340.7
# 1999 [YR1999]      26796
# 2000 [YR2000]    23718.7
# 2001 [YR2001]    23687.3
# 2002 [YR2002]    25205.2
# 2003 [YR2003]      30360
# 2004 [YR2004]    34165.9
# 2005 [YR2005]    34696.6
# 2006 [YR2006]    36447.9
# 2007 [YR2007]    41814.8
# 2008 [YR2008]    45699.2
# 2009 [YR2009]    41732.7
# 2010 [YR2010]      41788
# 2011 [YR2011]    45936.1
# 2012 [YR2012]    44010.9
# 2013 [YR2013]    45600.8
# 2014 [YR2014]      47767
# 2015 [YR2015]      41219
# Name: 4, dtype: object

# %%
year_list ={1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015}

# %%
year_list = pd.DataFrame(year_list)

# %%
year_list
# Out:
#        0
# 0   1990
# 1   1991
# 2   1992
# 3   1993
# 4   1994
# 5   1995
# 6   1996
# 7   1997
# 8   1998
# 9   1999
# 10  2000
# 11  2001
# 12  2002
# 13  2003
# 14  2004
# 15  2005
# 16  2006
# 17  2007
# 18  2008
# 19  2009
# 20  2010
# 21  2011
# 22  2012
# 23  2013
# 24  2014
# 25  2015

# %%
gdp_df_t_ger = pd.DataFrame(gdp_df_t_ger)

# %%
gdp_df_t_ger
# Out:
#                      4
# 1990 [YR1990]  22219.6
# 1991 [YR1991]  23269.4
# 1992 [YR1992]  26333.5
# 1993 [YR1993]  25488.5
# 1994 [YR1994]  27087.6
# 1995 [YR1995]  31729.7
# 1996 [YR1996]  30564.2
# 1997 [YR1997]  27045.7
# 1998 [YR1998]  27340.7
# 1999 [YR1999]    26796
# 2000 [YR2000]  23718.7
# 2001 [YR2001]  23687.3
# 2002 [YR2002]  25205.2
# 2003 [YR2003]    30360
# 2004 [YR2004]  34165.9
# 2005 [YR2005]  34696.6
# 2006 [YR2006]  36447.9
# 2007 [YR2007]  41814.8
# 2008 [YR2008]  45699.2
# 2009 [YR2009]  41732.7
# 2010 [YR2010]    41788
# 2011 [YR2011]  45936.1
# 2012 [YR2012]  44010.9
# 2013 [YR2013]  45600.8
# 2014 [YR2014]    47767
# 2015 [YR2015]    41219

# %%
gdp_df_t_pol = pd.DataFrame(gdp_df_t_pol)

# %%
gdp_df_t_pol
# Out:
#                      0
# 1990 [YR1990]  1698.01
# 1991 [YR1991]  2192.67
# 1992 [YR1992]  2411.86
# 1993 [YR1993]   2449.3
# 1994 [YR1994]  2819.69
# 1995 [YR1995]  3612.16
# 1996 [YR1996]  4066.84
# 1997 [YR1997]  4076.35
# 1998 [YR1998]  4483.24
# 1999 [YR1999]  4351.37
# 2000 [YR2000]  4492.73
# 2001 [YR2001]   4981.2
# 2002 [YR2002]  5196.93
# 2003 [YR2003]  5693.38
# 2004 [YR2004]  6639.96
# 2005 [YR2005]  7976.07
# 2006 [YR2006]  8999.74
# 2007 [YR2007]  11247.6
# 2008 [YR2008]  13906.2
# 2009 [YR2009]  11440.6
# 2010 [YR2010]  12597.5
# 2011 [YR2011]  13891.1
# 2012 [YR2012]    13142
# 2013 [YR2013]  13776.5
# 2014 [YR2014]  14337.2
# 2015 [YR2015]  12494.5

# %%
plt.plot(year_list[0],gdp_df_t_pol[0])
plt.xlabel('Years')
plt.ylabel('GDP percaipta in US$')
plt.plot(year_list[0],gdp_df_t_ger[4])
plt.legend(['Poland','Germany'])
plt.title('GDP percapita in US$ Poland & Germany')
# Out:
# Text(0.5, 1.0, 'GDP percapita in US$ Poland & Germany')

# %%
gdp_df_t_pol_growth=  gdp_df_t_pol/gdp_df_t_pol.iloc[0] *100
gdp_df_t_ger_growth=  gdp_df_t_ger/gdp_df_t_ger.iloc[0] *100

# %%
gdp_df_t_ger_growth
# Out:
#                      4
# 1990 [YR1990]      100
# 1991 [YR1991]  104.725
# 1992 [YR1992]  118.515
# 1993 [YR1993]  114.712
# 1994 [YR1994]  121.909
# 1995 [YR1995]  142.801
# 1996 [YR1996]  137.556
# 1997 [YR1997]   121.72
# 1998 [YR1998]  123.048
# 1999 [YR1999]  120.596
# 2000 [YR2000]  106.747
# 2001 [YR2001]  106.606
# 2002 [YR2002]  113.437
# 2003 [YR2003]  136.636
# 2004 [YR2004]  153.765
# 2005 [YR2005]  156.153
# 2006 [YR2006]  164.035
# 2007 [YR2007]  188.189
# 2008 [YR2008]  205.671
# 2009 [YR2009]   187.82
# 2010 [YR2010]  188.069
# 2011 [YR2011]  206.737
# 2012 [YR2012]  198.073
# 2013 [YR2013]  205.228
# 2014 [YR2014]  214.977
# 2015 [YR2015]  185.508

# %%
plt.plot(year_list[0],gdp_df_t_pol_growth[0])
plt.plot(year_list[0],gdp_df_t_ger_growth[4])
plt.xlabel('Years')
plt.ylabel('GDP Grwoth')
plt.legend(['Poland','Germany'])
plt.title('GDP Growth in Poland & Germany')
# Out:
# Text(0.5, 1.0, 'GDP Growth in Poland & Germany')
