# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
import datetime

# %%
obama_tb = pd.read_csv('D:\\Python\\Python36\\Practice\\obama_too_big.csv', parse_dates=['year_month'])

# %%
obama_tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65499 entries, 0 to 65498
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year_month           65499 non-null  datetime64[ns]
#  1   survey_organization  65499 non-null  object
#  2   approve_percent      65499 non-null  float64
#  3   disapprove_percent   65499 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 2.0+ MB

# %%
obama_tb
# Out:
#       year_month  survey_organization  approve_percent  disapprove_percent
# 0     2009-01-01       Generated Data             67.0                31.0
# 1     2009-01-01       Harris (Phone)             60.0                29.0
# 2     2009-01-01       Generated Data             65.9                19.1
# 3     2009-01-01       Generated Data             64.6                18.4
# 4     2009-01-01       Generated Data             83.3                11.7
# ...          ...                  ...              ...                 ...
# 65494 2016-01-01       Generated Data             50.2                45.8
# 65495 2016-01-01       Generated Data             41.0                55.0
# 65496 2015-12-01  Monmouth University             36.0                53.0
# 65497 2016-01-01       Generated Data             46.8                49.2
# 65498 2016-01-01       Generated Data             40.2                53.8
#
# [65499 rows x 4 columns]

# %%
obama_tb.shape
# Out:
# (65499, 4)

# %%
plt.plot(obama_tb['year_month'],obama_tb.approve_percent, 'o', markersize=2,alpha=0.2)

# %% [markdown]
# #Sampling

# %%
sample_obama = obama_tb.sample(frac=0.1)
ss = obama_tb.sample(n=1000)
sample_obama.size
# Out:
# 26200

# %%
plt.plot(sample_obama.year_month, sample_obama.approve_percent,'o', markersize=2, alpha=0.2)

# %%
ss.size
# Out:
# 4000

# %%
plt.plot(ss.year_month, ss.approve_percent,'o', markersize=3, alpha=0.2)
